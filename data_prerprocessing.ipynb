# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("olive_review_11to20_0616.csv")

# %%
data_temp = data[['상품명','리뷰']]

# %%
data_temp.isnull().sum()
# Out:
# 상품명    0
# 리뷰     0
# dtype: int64

# %%
data_temp = data_temp.dropna()

# %%
data_temp['리뷰'].iloc[3]
# Out:
# '‼️남자친구 주려고 매장에서 이것저것 다테스트 해보고 골랐어요! 남자친구는➡️ 건성⬅️이고 요즘 마스크때문에 안나던 💥뾰루지나 홍조💥가 심해지더라구요..가뜩이나 뭐안바르고 방치하니까..근데 또 ⚠️⚠️취향이 까다로워서 끈적이는거 바르면☹😦 꽤ㆍ에에엑😱 소리지르면서 도망가요 진짜ㅡㅡ 흡수될때까지 ❗엥엥😟대고 😡입술 다터도 겨울에도 립밤 끈적이는거 싫다고 피범벅되도 죽어도 안발라서 잘때 몰래발라줘야 되는사람이에요..다음날 본인도 알아요 입술이 괜찮아지니까 몰래 발라줬냐고..하여튼 이렇게 ‼️✅끈적이는거 절대 안쓰고 ✅무향을 좋아해서 골랐는데\n➡️얘는 정말 제형이 여성분들이라면 아실텐데 아이프라이머나 프라이머 그 모공채우는 제형들은 정말 보들하게 올라가고 끈적임 없이 흡수되잖아요 딱 그제형❗✅ 완전 보들보들 흡수 끝 흡수 정말 순삭 진짜 향도 거의 ✅무향 올인원이고 성분도 진정성분착하고 미백잡티케어에 수분감은 뭐 당연하고 이거 제가 바르고싶을정도..가끔 뺏어쓰다가 좋으면 나도..사야지.. 바르곤 빼애액안하고 엥엥 안하는거보니 취향저격🔫은 했는데 🙏🙏제발 꾸준히 발랐으면좋겠네요 🙏🙏하...😩피부좋은거 믿고 맨날 술마시더니...너도 늙는구나..역시 타고나도 관리는 필요한가봐요\U0001f9d0\n※ 해당 리뷰는 원칙적으로 기본 상품이 동일한 단품 사용 후 작성된 것이며,개별 상품에 따라 용량 내지 일부 구성(1+1, 기획상품 등)이 상이할 수 있음을 안내드립니다.\n남친올인원추천 끈적임없음 올인원추천'

# %%
data_temp
# Out:
#                                                 상품명  \
# 0     닥터지 레드 블레미쉬 포 맨 올인원 플루이드 (본품150ml+30ml 추가 증정)
# 1     닥터지 레드 블레미쉬 포 맨 올인원 플루이드 (본품150ml+30ml 추가 증정)
# 2     닥터지 레드 블레미쉬 포 맨 올인원 플루이드 (본품150ml+30ml 추가 증정)
# 3     닥터지 레드 블레미쉬 포 맨 올인원 플루이드 (본품150ml+30ml 추가 증정)
# 4     닥터지 레드 블레미쉬 포 맨 올인원 플루이드 (본품150ml+30ml 추가 증정)
# ...                                             ...
# 7281        싸이닉 더 심플 스킨케어 2종 기획 (토너145mlx2+로션145ml)
# 7282        싸이닉 더 심플 스킨케어 2종 기획 (토너145mlx2+로션145ml)
# 7283        싸이닉 더 심플 스킨케어 2종 기획 (토너145mlx2+로션145ml)
# 7287        싸이닉 더 심플 스킨케어 2종 기획 (토너145mlx2+로션145ml)
# 7289        싸이닉 더 심플 스킨케어 2종 기획 (토너145mlx2+로션145ml)
#
#                                                      리뷰
# 0     올인원 잘 만들어진 제품!!\n피부타입\n건성에 좋아요\n피부고민\n보습에 좋아요\...
# 1     [옵션] 기획\n피부타입\n복합성에 좋아요\n피부고민\n진정에 좋아요\n자극도\n자...
# 2     [옵션] 기획\n피부타입\n복합성에 좋아요\n피부고민\n보습에 좋아요\n자극도\n자...
# 3     ‼️남자친구 주려고 매장에서 이것저것 다테스트 해보고 골랐어요! 남자친구는➡️ 건성...
# ...

# %%
target_string = ['피부타입', '복합성에 좋아요', '피부고민', '진정에 좋아요', '자극도', '자극없이 순해요']
data2 = data_temp[~data_temp['리뷰'].map(lambda x: all(string in x for string in target_string))]

# %%
target_string = ['피부타입', '피부고민', '자극도']
data2 = data_temp[~data_temp['리뷰'].map(lambda x: all(string in x for string in target_string))]

# %%
data2.to_csv('preprocessing.csv', encoding='utf-8-sig')

# %%
temp.to_csv("review_12800to13462.csv", encoding='utf-8-sig') # labeling[1833:2033]

# %%
data2

# %%
1900~~

1900~2100
2100~2300
2300~2500
2500~2700
2700~2900


2900~3100
3100~3300
3300~3500
3500~3700
3700~3900
